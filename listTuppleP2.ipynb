# %% [markdown]
# <a href="https://colab.research.google.com/github/sandeshshirse/Python/blob/main/listTuppleP2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name : Sandesh Shire
# Roll No 12
#
# Practical no 2
# Aim : To create List and Tupple

# %% [markdown]
# List

# %%
movie = ["kabir singh", "laila majnu", "sairat"]
print(movie[2])
# Out:
# sairat

# %%
movie.append("O' Romeo")
print(movie)
# Out:
# ['kabir singh', 'laila majnu', 'sairat', "O' Romeo"]

# %%
movie.pop(1)
print(movie)
# Out:
# ['kabir singh', 'sairat', "O' Romeo"]

# %%
movie.sort()
print(movie)
# Out:
# ["O' Romeo", 'kabir singh', 'sairat']

# %%
newMovie = []
newMovie = [movie[0], movie[-1]]
print(newMovie)
# Out:
# ["O' Romeo", 'sairat']

# %% [markdown]
# Tupple

# %%
foods = ("vadapaav", "samosa", "kachori")
print(foods)
# Out:
# ('vadapaav', 'samosa', 'kachori')

# %%
print(foods[1])
# Out:
# samosa

# %%
foods[1] = "noodles"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1556/3476218704.py in <cell line: 0>()
# ----> 1 foods[1] = "noodles"
#
# TypeError: 'tuple' object does not support item assignment

# %%
print("second food :", foods[1])
# Out:
# second food : samosa

# %%
newFoods = (foods[0], foods[-1])
print(newFoods)
# Out:
# ('vadapaav', 'kachori')

# %%
print(len(foods))
# Out:
# 3

# %%
foodList = list(foods)
print(foodList)
# Out:
# ['vadapaav', 'samosa', 'kachori']
